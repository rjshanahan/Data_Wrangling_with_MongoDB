# %%
##LESSON 2: Q1 - MY ANSWER


#!/usr/bin/env python
# Your task here is to extract data from xml on authors of an article
# and add it to a list, one item for an author.
# See the provided data structure for the expected format.
# The tags for first name, surname and email should map directly
# to the dictionary keys
import xml.etree.ElementTree as ET

article_file = "exampleResearchArticle.xml"


def get_root(fname):
    global tree
    tree = ET.parse(fname)
    #root = tree.getroot()
    #for child in root:
    #    print child.tag
    return tree.getroot()


def get_authors(root):
    global authors
    authors = []
    for author in root.findall('./fm/bibl/aug/au'):
        data = {
                "fnm": None,
                "snm": None,
                "email": None
        }
        ######
        #data["fnm"] = author[1].text
        #data["snm"] = author[0].text
        #data["email"] = author[3].text
        data["fnm"] = author.find('./fnm').text
        data["snm"] = author.find('./snm').text
        data["email"] = author.find('./email').text
        
        authors.append(data)

    return authors


def test():
    solution = [{'fnm': 'Omer', 'snm': 'Mei-Dan', 'email': 'omer@extremegate.com'}, 
                {'fnm': 'Mike', 'snm': 'Carmont', 'email': 'mcarmont@hotmail.com'}, 
                {'fnm': 'Lior', 'snm': 'Laver', 'email': 'laver17@gmail.com'}, 
                {'fnm': 'Meir', 'snm': 'Nyska', 'email': 'nyska@internet-zahav.net'}, 
                {'fnm': 'Hagay', 'snm': 'Kammar', 'email': 'kammarh@gmail.com'}, 
                {'fnm': 'Gideon', 'snm': 'Mann', 'email': 'gideon.mann.md@gmail.com'}, 
                {'fnm': 'Barnaby', 'snm': 'Clarck', 'email': 'barns.nz@gmail.com'}, 
                {'fnm': 'Eugene', 'snm': 'Kots', 'email': 'eukots@gmail.com'}]
    
    root = get_root(article_file)
    data = get_authors(root)

    assert data[0] == solution[0]
    assert data[1]["fnm"] == solution[1]["fnm"]


test()
# Out:
# [<Element 'au' at 0x1051b4710>, <Element 'au' at 0x1051b4890>, <Element 'au' at 0x1051b4a10>, <Element 'au' at 0x1051b4b90>, <Element 'au' at 0x1051b4d10>, <Element 'au' at 0x1051b4e50>, <Element 'au' at 0x105169050>, <Element 'au' at 0x105169190>]
# [<Element 'au' at 0x1051b4710>, <Element 'au' at 0x1051b4890>, <Element 'au' at 0x1051b4a10>, <Element 'au' at 0x1051b4b90>, <Element 'au' at 0x1051b4d10>, <Element 'au' at 0x1051b4e50>, <Element 'au' at 0x105169050>, <Element 'au' at 0x105169190>]
# [<Element 'au' at 0x1051b4710>, <Element 'au' at 0x1051b4890>, <Element 'au' at 0x1051b4a10>, <Element 'au' at 0x1051b4b90>, <Element 'au' at 0x1051b4d10>, <Element 'au' at 0x1051b4e50>, <Element 'au' at 0x105169050>, <Element 'au' at 0x105169190>]
# ...

# %%
##LESSON 2: Q2 - MY ANSWER

#!/usr/bin/env python
# Your task here is to extract data from xml on authors of an article
# and add it to a list, one item for an author.
# See the provided data structure for the expected format.
# The tags for first name, surname and email should map directly
# to the dictionary keys, but you have to extract the attributes from the "insr" tag
# and add them to the list for the dictionary key "insr"
import xml.etree.ElementTree as ET

article_file = "exampleResearchArticle.xml"


def get_root(fname):
    tree = ET.parse(fname)
    return tree.getroot()


def get_authors(root):
    global authors
    authors = []
    for author in root.findall('./fm/bibl/aug/au'):
        data = {
                "fnm": None,
                "snm": None,
                "email": None,
                "insr": []
        }
        data["fnm"] = author.find('./fnm').text
        data["snm"] = author.find('./snm').text
        data["email"] = author.find('./email').text
        for child in author.findall('./insr'):
            data["insr"].append(child.attrib["iid"])
            

        authors.append(data)

    return authors


def test():
    solution = [{'insr': ['I1'], 'fnm': 'Omer', 'snm': 'Mei-Dan', 'email': 'omer@extremegate.com'},
                {'insr': ['I2'], 'fnm': 'Mike', 'snm': 'Carmont', 'email': 'mcarmont@hotmail.com'},
                {'insr': ['I3', 'I4'], 'fnm': 'Lior', 'snm': 'Laver', 'email': 'laver17@gmail.com'},
                {'insr': ['I3'], 'fnm': 'Meir', 'snm': 'Nyska', 'email': 'nyska@internet-zahav.net'},
                {'insr': ['I8'], 'fnm': 'Hagay', 'snm': 'Kammar', 'email': 'kammarh@gmail.com'},
                {'insr': ['I3', 'I5'], 'fnm': 'Gideon', 'snm': 'Mann', 'email': 'gideon.mann.md@gmail.com'},
                {'insr': ['I6'], 'fnm': 'Barnaby', 'snm': 'Clarck', 'email': 'barns.nz@gmail.com'},
                {'insr': ['I7'], 'fnm': 'Eugene', 'snm': 'Kots', 'email': 'eukots@gmail.com'}]

    root = get_root(article_file)
    data = get_authors(root)

    assert data[0] == solution[0]
    assert data[1]["insr"] == solution[1]["insr"]


test()
def test():
    solution = [{'fnm': 'Omer', 'snm': 'Mei-Dan', 'email': 'omer@extremegate.com'}, 
                {'fnm': 'Mike', 'snm': 'Carmont', 'email': 'mcarmont@hotmail.com'}, 
                {'fnm': 'Lior', 'snm': 'Laver', 'email': 'laver17@gmail.com'}, 
                {'fnm': 'Meir', 'snm': 'Nyska', 'email': 'nyska@internet-zahav.net'}, 
                {'fnm': 'Hagay', 'snm': 'Kammar', 'email': 'kammarh@gmail.com'}, 
                {'fnm': 'Gideon', 'snm': 'Mann', 'email': 'gideon.mann.md@gmail.com'}, 
                {'fnm': 'Barnaby', 'snm': 'Clarck', 'email': 'barns.nz@gmail.com'}, 
                {'fnm': 'Eugene', 'snm': 'Kots', 'email': 'eukots@gmail.com'}]
    
    root = get_root(article_file)
    data = get_authors(root)

    assert data[0] == solution[0]
    assert data[1]["fnm"] == solution[1]["fnm"]


test()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-138-2942de35291f> in <module>()
#      75
#      76
# ---> 77 test()
#      78
#      79
#
# <ipython-input-138-2942de35291f> in test()
#      71     data = get_authors(root)
#      72
# ---> 73     assert data[0] == solution[0]
#      74     assert data[1]["fnm"] == solution[1]["fnm"]
#      75
#
# AssertionError:

# %%
#####FXRATE XML PARSER

#!/usr/bin/env python

import xml.etree.ElementTree as ET

ratesfile = "fxrates.xml"

def get_root(fname):
    tree = ET.parse(fname)
    return tree.getroot()

def fx_xml_parser():
    rates = []
    
    root = get_root(ratesfile)

    for fxrate in root.findall('./ForExRateSheetRec/ForExRateSheetInfo/ForExRateSheetCurRate/ForExRate'):
        data = {
                "BaseCurCode": None,
                "ContraCurCode": None,
                "ExchRate": None,
                "Date": None
                }
    
        data["BaseCurCode"] = fxrate.find('./BaseCurCode/Value').text
        data["ContraCurCode"] = fxrate.find('./ContraCurCode/Value').text
        data["ExchRate"] = fxrate.find('./ExchRate').text
        data["Date"] = '02-01-2015'
    
        rates.append(data)
        
    
    return rates

fx_xml_parser()
# Out:
# [{'BaseCurCode': 'AUD',
#   'ContraCurCode': 'CYP',
#   'Date': '02-01-2015',
#   'ExchRate': '0.35'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'CZK',
#   'Date': '02-01-2015',
#   'ExchRate': '18.13'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'DKK',
#   'Date': '02-01-2015',
#   'ExchRate': '4.92'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'DJF',
#   'Date': '02-01-2015',
#   'ExchRate': '157.55'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'DOP',
#   'Date': '02-01-2015',
#   'ExchRate': '38.57'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'ECD',
#   'Date': '02-01-2015',
#   'ExchRate': '3.11'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'ECS',
#   'Date': '02-01-2015',
#   'ExchRate': '22410'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'EGP',
#   'Date': '02-01-2015',
#   'ExchRate': '6.27'},
#  {'BaseCurCode': 'AUD',
#   'ContraCurCode': 'ETB',
#   'Date': '02-01-2015',
#   'ExchRate': '17.19'},
#  {'BaseCurCode': 'AUD',
# ...

# %%
##### LESSON 2: HTML web scraping

#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Please note that the function 'make_request' is provided for your reference only.
# You will not be able to to actually use it from within the Udacity web UI.
# Your task is to process the HTML using BeautifulSoup, extract the hidden
# form field values for "__EVENTVALIDATION" and "__VIEWSTATE" and set the approprate
# values in the data dictionary.
# All your changes should be in the 'extract_data' function
from bs4 import BeautifulSoup
import requests
import json

html_page = "view-source www.transtats.bts.gov Data_Elements.aspx Data=2.html"

#name="__EVENTVALIDATION"

def extract_data(page):
    data = {"eventvalidation": "",
            "viewstate": ""}
    with open(page, "r") as html:
        # do something here to find the necessary values
        
        soup = BeautifulSoup(html, "html.parser")        #you need to specify "html.parser" otherwise long strings are missed

        data["viewstate"] = soup.find(attrs= {'id':"__VIEWSTATE"})['value']
        data["eventvalidation"] = soup.find(attrs= {'id':"__EVENTVALIDATION"})['value']
   
        ###UDACITY solution
        #ev = soup.find(id="__EVENTVALIDATION")
        #data["eventvalidation"] = ev["value"]

        #vs = soup.find(id="__VIEWSTATE")
        #data["viewstate"] = vs["value"]

        print data

        pass

    return data


def make_request(data):
    eventvalidation = data["eventvalidation"]
    viewstate = data["viewstate"]

    r = requests.post("http://www.transtats.bts.gov/Data_Elements.aspx?Data=2",
                    data={'AirportList': "BOS",
                          'CarrierList': "VX",
                          'Submit': 'Submit',
                          "__EVENTTARGET": "",
                          "__EVENTARGUMENT": "",
                          "__EVENTVALIDATION": eventvalidation,
                          "__VIEWSTATE": viewstate
                    })

    return r.text


def test():
    data = extract_data(html_page)
    assert data["eventvalidation"] != ""
    assert data["eventvalidation"].startswith("/wEWjAkCoIj1ng0")
    assert data["viewstate"].startswith("/wEPDwUKLTI")

    
test()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-91-e79f4a8c8bdf> in <module>()
#      63
#      64
# ---> 65 test()
#
# <ipython-input-91-e79f4a8c8bdf> in test()
#      59     data = extract_data(html_page)
#      60     assert data["eventvalidation"] != ""
# ---> 61     assert data["eventvalidation"].startswith("/wEWjAkCoIj1ng0")
#      62     assert data["viewstate"].startswith("/wEPDwUKLTI")
#      63
#
# AssertionError:
# {'eventvalidation': u'...', 'viewstate': u'...'}

# %%
####LESSON 2 Problem Set Q1

#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Please note that the function 'make_request' is provided for your reference only.
# You will not be able to to actually use it from within the Udacity web UI
# All your changes should be in the 'extract_carrier' function
# Also note that the html file is a stripped down version of what is actually on the website.

# Your task in this exercise is to get a list of all airlines. Exclude all of the combination
# values, like "All U.S. Carriers" from the data that you return.
# You should return a list of codes for the carriers.

from bs4 import BeautifulSoup
html_page = "options.html"


def extract_carriers(page):
    global data
    global soup
    
    data = []
    
    removelist_all = ['All','AllUS','AllForeign','AllMajors','AllOthers','All']
    removelist = []
    
    with open(page, "r") as html:
        ##### MY ANSWER
        soup = BeautifulSoup(html, "html.parser")
        
        #combined list
        soup_option = soup.find_all('option')
        for i in soup_option:
            data.append(i['value'])
        
        for r in removelist_all:
            data.remove(r) 
            
        #carriers only - uses full list and trims on length
        for c in data:
            if len(c) == 3:
                removelist.append(c)

        for k in removelist:
            data.remove(k)
        
    return data


def make_request(data):
    eventvalidation = data["eventvalidation"]
    viewstate = data["viewstate"]
    airport = data["airport"]
    carrier = data["carrier"]

    r = requests.post("http://www.transtats.bts.gov/Data_Elements.aspx?Data=2",
                    data={'AirportList': airport,
                          'CarrierList': carrier,
                          'Submit': 'Submit',
                          "__EVENTTARGET": "",
                          "__EVENTARGUMENT": "",
                          "__EVENTVALIDATION": eventvalidation,
                          "__VIEWSTATE": viewstate
                    })

    return r.text


def test():
    data = extract_carriers(html_page)
    assert len(data) == 16
    assert "FL" in data
    assert "NK" in data

test()

# %%
####LESSON 2 Problem Set Q2

#!/usr/bin/env python
# -*- coding: utf-8 -*-
# All your changes should be in the 'extract_airports' function
# It should return a list of airport codes, excluding any combinations like "All"

from bs4 import BeautifulSoup
html_page = "options.html"


def extract_airports(page):
    global data
    global soup
    
    data = []
    
    removelist_all = ['All','AllUS','AllForeign','AllMajors','AllOthers','All']
    removelist = []
    
    with open(page, "r") as html:
        ##### MY ANSWER
        soup = BeautifulSoup(html, "html.parser")
        
        #combined list
        soup_option = soup.find_all('option')
        for i in soup_option:
            data.append(i['value'])
        
        for r in removelist_all:
            data.remove(r) 
            
        #carriers only - uses full list and trims on length
        for c in data:
            if len(c) == 2:
                removelist.append(c)

        for k in removelist:
            data.remove(k)
        
    return data


def make_request(data):
    eventvalidation = data["eventvalidation"]
    viewstate = data["viewstate"]
    airport = data["airport"]
    carrier = data["carrier"]

    r = requests.post("http://www.transtats.bts.gov/Data_Elements.aspx?Data=2",
                    data={'AirportList': airport,
                          'CarrierList': carrier,
                          'Submit': 'Submit',
                          "__EVENTTARGET": "",
                          "__EVENTARGUMENT": "",
                          "__EVENTVALIDATION": eventvalidation,
                          "__VIEWSTATE": viewstate
                    })

    return r.text


def test():
    data = extract_airports(html_page)
    assert len(data) == 15
    assert "ATL" in data
    assert "ABR" in data

test()

# %%
### LESSON 2 Question 3

#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Let's assume that you combined the code from the previous 2 exercises
# with code from the lesson on how to build requests, and downloaded all the data locally.
# The files are in a directory "data", named after the carrier and airport:
# "{}-{}.html".format(carrier, airport), for example "FL-ATL.html".
# The table with flight info has a table class="dataTDRight".
# There are couple of helper functions to deal with the data files.
# Please do not change them for grading purposes.
# All your changes should be in the 'process_file' function
# This is example of the datastructure you should return
# Each item in the list should be a dictionary containing all the relevant data
# Note - year, month, and the flight data should be integers
# You should skip the rows that contain the TOTAL data for a year
# data = [{"courier": "FL",
#         "airport": "ATL",
#         "year": 2012,
#         "month": 12,
#         "flights": {"domestic": 100,
#                     "international": 100}
#         },
#         {"courier": "..."}
# ]
from bs4 import BeautifulSoup
from zipfile import ZipFile
import os

datadir = "data"
filestatic = 'FL-ATL.html'

def open_zip(datadir):
    with ZipFile('{0}.zip'.format(datadir), 'r') as myzip:
        myzip.extractall()


def process_all(datadir):
    files = os.listdir(datadir)
    return files


def process_file(f):
    global info
    global data
    global soup
    global soup_dataTDRight
    global tabledata
    # This is example of the datastructure you should return
    # Each item in the list should be a dictionary containing all the relevant data
    # Note - year, month, and the flight data should be integers
    # You should skip the rows that contain the TOTAL data for a year
    # data = [{"courier": "FL",
    #         "airport": "ATL",
    #         "year": 2012,
    #         "month": 12,
    #         "flights": {"domestic": 100,
    #                     "international": 100}
    #         },
    #         {"courier": "..."}
    # ]
    data = []
    tabledata=[]
    tabledata_clean=[]
        
    #with open("{}/{}".format(datadir, f), "r") as html:
    with open(filestatic, "r") as html:

        soup = BeautifulSoup(html)
        
        #build table of raw but relevant data from HTML
        soup_dataTDRight = soup.find('table', attrs= {'class':"dataTDRight"})
        
        #refine HTML to table specific - loop through rows and columns
        rows = soup_dataTDRight.find_all('tr')
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            tabledata.append([ele for ele in cols if ele]) 
        
        #remove header row and rows with total
        for i in tabledata:
            if i[0] == 'Year' or i[1] == 'TOTAL':
                del i
            else:
                tabledata_clean.append(i)
        
        #build list of dictionaries
        for i in tabledata_clean:
            info = {}
            info["courier"], info["airport"] = 'FL-ATL'.split("-")
            #info["courier"], info["airport"] = f[:6].split("-")
            info["year"] = int(i[0])
            info["month"] = int(i[1])
            info["flights"] = {}
            info["flights"]["domestic"] = int(i[2].replace(',', ''))
            info["flights"]["international"] = int(i[3].replace(',', ''))
            data.append(info)
            
        #remove irrelevant collumns
        #for i in tabledata:
        #    print i[1:4]
           
        # remove first and last rows
        #tabledata[1:(len(tabledata)-1)]       

    return data


def test():
    print "Running a simple test..."
    open_zip(datadir)
    files = process_all(datadir)
    data = []
    for f in files:
        data += process_file(f)
    #assert len(data) == 399
    for entry in data[:3]:
        assert type(entry["year"]) == int
        assert type(entry["flights"]["domestic"]) == int
        assert len(entry["airport"]) == 3
        assert len(entry["courier"]) == 2
    assert data[-1]["airport"] == "ATL"
    assert data[-1]["flights"] == {'international': 108289, 'domestic': 701425}
    
    print "... success!"

if __name__ == "__main__":
    test()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-506-0d477b0481f4> in <module>()
#     123
#     124 if __name__ == "__main__":
# --> 125     test()
#
# <ipython-input-506-0d477b0481f4> in test()
#     118         assert len(entry["courier"]) == 2
#     119     assert data[-1]["airport"] == "ATL"
# --> 120     assert data[-1]["flights"] == {'international': 108289, 'domestic': 701425}
#     121
#     122     print "... success!"
#
# AssertionError:
# Running a simple test...

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# So, the problem is that the gigantic file is actually not a valid XML, because
# it has several root elements, and XML declarations.
# It is, a matter of fact, a collection of a lot of concatenated XML documents.
# So, one solution would be to split the file into separate documents,
# so that you can process the resulting files as valid XML documents.

import xml.etree.ElementTree as ET
PATENTS = 'patent.data'

def get_root(fname):
    tree = ET.parse(fname)
    return tree.getroot()


def split_file(filename):
    global doc
    global idxlist
    global idxdict
    global idxiter
    newdoc = '<?xml version="1.0" encoding="UTF-8"?>\n'
    idxlist = []
    idxdict = {}

    #open file and readlines - create list of line numbers where new XML docs start
    with open(filename, "r") as f:
        doc = f.readlines()
        for i, line in enumerate(doc):
            if line == newdoc:
                idxlist.append(i)
        idxlist.append(len(doc))
       
    #create ITERATOR of lines where XML starts
    idxiter = iter(idxlist[1:])

    #loop through iterator and construct dictionary of key=doc start, value=doc end
    while True:
        try:
            for i in idxlist:
                idxdict[i] = idxiter.next()
        except StopIteration:
            break        

    #write files based on dictionary values
    for i in idxlist[0:len(idxlist)-1]:
        with open('{}-{}'.format(filename, idxlist.index(i)), 'w') as f:
            f.writelines(doc[int(i):int(idxdict[i])])
        
    pass


def test():
    split_file(PATENTS)
    for n in range(4):
        try:
            fname = "{}-{}".format(PATENTS, n)
            f = open(fname, "r")
            if not f.readline().startswith("<?xml"):
                print "You have not split the file {} in the correct boundary!".format(fname)
            f.close()
        except:
            print "Could not find file {}. Check if the filename is correct!".format(fname)


test()
